# %% [markdown]
# # Job Descriptions
#
#  Here I will upload all job descriptions I went through and what they are asking for in terms of skills and experience. Based on the tasks for today, I will upload links to job descriptions.

# %% [markdown]
# >> Entry Level Jobs (Interships Mostly) (7 Job)
#
# https://careers.sysco.com/en/job/-/-/1105/85658756896?p_sid=tSOUwHb&p_uid=80cg5zL3R0&source=rd_linkedinslots&ss=paid&utm_campaign=sysco&utm_content=pj_board&utm_medium=jobad&utm_source=linkedin+slotted
#
# * AI/ML a plus
# * SQL/Python experience
# * Identify various business issues, and provide solutions via research
# * working relationships with client personnel
#
#
# https://lifeattiktok.com/search/7595672941112314117?spread=5MWH5CQ
#
# * Experience with coding (SQL, Python, etc.)
# * ability to translate business needs into technical solutions and data metrics
# * understanding of data warehousing and the construction ideas of the data system.
# * Understanding business problems, designing and implementing easy-to-use data solutions for businesses.
#
#
# https://www.adzuna.com/details/5626818776?v=D140FD5D27BAD7CA39A6C1819204F9EBF6D5BC79&ccd=894de079dc6d4b02471dee47797f66ba&r=21351267&frd=36c997748aed2da13a5b3372a78ae625&utm_source=linkedin7&utm_medium=organic&chnlid=1931&title=Data%20Engineer%20Intern%20%2849553%29&a=e
#
# * following programming in Python, SQL x2
# *  basic database and data handling processes
# * Knowledge of data engineering process and techniques.
# * Machine Learning Techniques
# * basic principles of software programming and database/data handling
# * ability to use Microsoft Office applications to create spreadsheets, Word documents, and presentation skills
# * Problem Solving and Trouble shooting
#
#
#
# https://www.tesla.com/careers/search/job/258360?source=LinkedIn
#
# https://job-boards.greenhouse.io/appliedintuition/jobs/4592025005?gh_jid=4592025005&source=LinkedIn
#
# https://jobs.lever.co/zoox/b9fb6f1d-31db-4a79-b70b-9396bf01b117/apply?source=LinkedIn
#
# https://lifeattiktok.com/search/7584219416980818229?spread=5MWH5CQ
